# %%
from bs4 import BeautifulSoup

# %% [markdown]
# # 3.Connect to the website using urllib.request

# %%
import urllib.request

url = "https://pythonprogramming.net/parsememcparseface/"  # Replace this with the URL of the website you want to connect to

with urllib.request.urlopen(url) as response:# Open the URL and read the HTML content
    html_content = response.read()

print(html_content.decode('utf-8'))
# Out:
# <html>
# 	<head>
#
# 		<!--
# 		palette:
# 		dark blue: #003F72
# 		yellow: #FFD166
# 		salmon: #EF476F
# 		offwhite: #e7d7d7
# 		Light Blue: #118AB2
# 		Light green: #7DDF64
# 		-->
#
# 		<meta name="viewport" content = "width=device-width, initial-scale=1.0">
# 		<title>Python Programming Tutorials</title>
#
# 		<meta name="description" content="Python Programming tutorials from beginner to advanced on a massive variety of topics. All video and text tutorials are free.">
#
# 		<link rel="shortcut icon" href="/static/favicon.ico">
# 		<link rel="stylesheet" href="/static/css/materialize.min.css">
#         <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet">
#         <meta name="google-site-verification" content="3fLok05gk5gGtWd_VSXbSSSH27F2kr1QqcxYz9vYq2k" />
#         <link rel="stylesheet" type="text/css" href="/static/css/bootstrap.css">
#
#
# 		  <!-- Compiled and minified CSS -->
#
# 		<!-- Compiled and minified JavaScript -->
#
# ...

# %% [markdown]
# # 4.Create an object called ‘soup’ using the source

# %%
soup = BeautifulSoup(html_content, 'html.parser')

# %% [markdown]
# # 5.Print page title, get attributes, values, and beginning navigation. Get specific values.

# %%
print("Page Title:", soup.title.text)

all_info = soup.find_all()
for X in all_info:
    for attribute, value in X.attrs.items():
        print(f"{attribute}: {value}")
# Out:
# Page Title: Python Programming Tutorials
# name: viewport
# content: width=device-width, initial-scale=1.0
# name: description
# content: Python Programming tutorials from beginner to advanced on a massive variety of topics. All video and text tutorials are free.
# rel: ['shortcut', 'icon']
# href: /static/favicon.ico
# rel: ['stylesheet']
# href: /static/css/materialize.min.css
# href: https://fonts.googleapis.com/icon?family=Material+Icons
# rel: ['stylesheet']
# name: google-site-verification
# content: 3fLok05gk5gGtWd_VSXbSSSH27F2kr1QqcxYz9vYq2k
# rel: ['stylesheet']
# type: text/css
# href: /static/css/bootstrap.css
# src: https://code.jquery.com/jquery-2.1.4.min.js
# src: https://cdnjs.cloudflare.com/ajax/libs/materialize/0.97.3/js/materialize.min.js
# async:
# src: //pagead2.googlesyndication.com/pagead/js/adsbygoogle.js
# class: ['navbar-fixed']
# style: background-color:#003F72
# class: ['nav-wrapper', 'container']
# href: /
# class: ['brand-logo']
# ...

# %%
#Print the beginning of the navigation section (e.g., the first 'nav' tag)
first_nav_tag = soup.find('nav')
print("\nBeginning of Navigation Section:",first_nav_tag.text)
# Out:
# Beginning of Navigation Section:
#
#
#
#
# search
#
#
#
#
#
# Home
# +=1
#
# Support the Content
# Community
# Log in
# Sign up
#
#
#
#
#
#
#
# Home
# +=1
#
# Support the Content
# Community
# Log in
# Sign up

# %% [markdown]
# # 6. Find all the paragraph instead of just one in the previous query
# # 7. You can iterate through them using ‘str(paragraph.text)’

# %%
all_paragraphs = soup.find_all('p')
print("\nAll Paragraphs:")
for paragraph in all_paragraphs:
    print(str(paragraph.text))
# Out:
# All Paragraphs:
# Oh, hello! This is a wonderful page meant to let you practice web scraping. This page was originally created to help people work with the Beautiful Soup 4 library.
# The following table gives some general information for the following programming languages:
# I think it's clear that, on a scale of 1-10, python is:
# Javascript (dynamic data) test:
# y u bad tho?
# Whᶐt hαppéns now¿
# sitemap
# Contact: Harrison@pythonprogramming.net.
# Programming is a superpower.

# %% [markdown]
# # 8. Grab all the links through ‘url.get(‘here)

# %%
all_links = [a.get('href') for a in soup.find_all('a')]
print("\nAll Links:")
for link in all_links:
    print(link)
# Out:
# All Links:
# /
# #
# /
# /+=1/
# /support/
# https://goo.gl/7zgAVQ
# /login/
# /register/
# /
# /+=1/
# /support/
# https://goo.gl/7zgAVQ
# /login/
# /register/
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/
# /sitemap.xml
# /support-donate/
# /consulting/
# https://www.facebook.com/pythonprogramming.net/
# https://twitter.com/sentdex
# https://instagram.com/sentdex
# /about/tos/
# /about/privacy-policy/
# https://xkcd.com/353/

# %% [markdown]
# # 9. Just grab the text using ‘get_text’

# %%
all_text = soup.get_text()
print("\nAll Text:")
print(all_text)
# Out:
# All Text:
#
#
#
#
# Python Programming Tutorials
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# search
#
#
#
#
#
# Home
# +=1
#
# Support the Content
# Community
# Log in
# Sign up
#
#
#
#
#
#
#
# Home
# +=1
#
# Support the Content
# Community
# Log in
# Sign up
#
#
#
#
#
#
#
#
#
#
# Oh, hello! This is a wonderful page meant to let you practice web scraping. This page was originally created to help people work with the Beautiful Soup 4 library.
# The following table gives some general information for the following programming languages:
#
# Python
# Pascal
# Lisp
# D#
# Cobol
# Fortran
# Haskell
#
#
#
# Program Name
# Internet Points
# Kittens?
#
#
# Python
# 932914021
# Definitely
#
#
# Pascal
# 532
# Unlikely
#
#
# Lisp
# 1522
# Uncertain
#
#
# D#
# 12
# Possibly
#
#
# Cobol
# 3
# No.
#
#
# Fortran
# 52124
# Yes.
#
#
# Haskell
# 24
# lol.
#
#
# I think it's clear that, on a scale of 1-10, python is:
#
#
#
#
#
#
# Javascript (dynamic data) test:
# y u bad tho?
#
#
# ...
